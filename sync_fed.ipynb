# %%
# !pip install -q 'flwr[simulation]' torch torchvision matplotlib
# Out:
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: pip install --upgrade pip

# %%
from collections import OrderedDict
from typing import List, Tuple

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import CIFAR10

import flwr as fl
from flwr.common import Metrics

DEVICE = torch.device("cpu")  # Try "cuda" to train on GPU
print(
    f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}"
)
# Out:
# Training on cpu using PyTorch 2.0.0 and Flower 1.3.0

# %%
CLASSES = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)

# %%
NUM_CLIENTS = 10
BATCH_SIZE = 32


def load_datasets():
    # Download and transform CIFAR-10 (train and test)
    transform = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
    )
    trainset = CIFAR10("./dataset", train=True, download=True, transform=transform)
    testset = CIFAR10("./dataset", train=False, download=True, transform=transform)

    # Split training set into 10 partitions to simulate the individual dataset
    partition_size = len(trainset) // NUM_CLIENTS
    lengths = [partition_size] * NUM_CLIENTS
    datasets = random_split(trainset, lengths, torch.Generator().manual_seed(42))

    # Split each partition into train/val and create DataLoader
    trainloaders = []
    valloaders = []
    for ds in datasets:
        len_val = len(ds) // 10  # 10 % validation set
        len_train = len(ds) - len_val
        lengths = [len_train, len_val]
        ds_train, ds_val = random_split(ds, lengths, torch.Generator().manual_seed(42))
        trainloaders.append(DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True))
        valloaders.append(DataLoader(ds_val, batch_size=BATCH_SIZE))
    testloader = DataLoader(testset, batch_size=BATCH_SIZE)
    return trainloaders, valloaders, testloader


trainloaders, valloaders, testloader = load_datasets()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
images, labels = next(iter(trainloaders[0]))

# Reshape and convert images to a NumPy array
# matplotlib requires images with the shape (height, width, 3)
images = images.permute(0, 2, 3, 1).numpy()
# Denormalize
images = images / 2 + 0.5

# Create a figure and a grid of subplots
fig, axs = plt.subplots(4, 8, figsize=(12, 6))

# Loop over the images and plot them
for i, ax in enumerate(axs.flat):
    ax.imshow(images[i])
    ax.set_title(CLASSES[labels[i]])
    ax.axis("off")

# Show the plot
fig.tight_layout()
plt.show()

# %%
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train(net, trainloader, epochs: int, verbose=False):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for epoch in range(epochs):
        correct, total, epoch_loss = 0, 0, 0.0
        for images, labels in trainloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # Metrics
            epoch_loss += loss
            total += labels.size(0)
            correct += (torch.max(outputs.data, 1)[1] == labels).sum().item()
        epoch_loss /= len(trainloader.dataset)
        epoch_acc = correct / total
        if verbose:
            print(f"Epoch {epoch+1}: train loss {epoch_loss}, accuracy {epoch_acc}")


def test(net, testloader):
    """Evaluate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy

# %%
trainloader = trainloaders[0]
valloader = valloaders[0]
net = Net().to(DEVICE)

for epoch in range(5):
    train(net, trainloader, 1)
    loss, accuracy = test(net, valloader)
    print(f"Epoch {epoch+1}: validation loss {loss}, accuracy {accuracy}")

loss, accuracy = test(net, testloader)
print(f"Final test set performance:\n\tloss {loss}\n\taccuracy {accuracy}")
# Out:
# Epoch 1: validation loss 0.05980895209312439, accuracy 0.284
# Epoch 2: validation loss 0.0570220935344696, accuracy 0.31
# Epoch 3: validation loss 0.05324087333679199, accuracy 0.368
# Epoch 4: validation loss 0.050917922735214234, accuracy 0.39
# Epoch 5: validation loss 0.05107085418701172, accuracy 0.424
# Final test set performance:
# 	loss 0.047715015935897824
# 	accuracy 0.446

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]


def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, net, trainloader, valloader):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config):
        return get_parameters(self.net)

    def fit(self, parameters, config):
        set_parameters(self.net, parameters)
        train(self.net, self.trainloader, epochs=1)
        return get_parameters(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_parameters(self.net, parameters)
        loss, accuracy = test(self.net, self.valloader)
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

# %%
def client_fn(cid: str) -> FlowerClient:
    """Create a Flower client representing a single organization."""

    # Load model
    net = Net().to(DEVICE)

    # Load data (CIFAR-10)
    # Note: each client gets a different trainloader/valloader, so each client
    # will train and evaluate on their own unique data
    trainloader = trainloaders[int(cid)]
    valloader = valloaders[int(cid)]

    # Create a  single Flower client representing a single organization
    return FlowerClient(net, trainloader, valloader)

# %%
# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,  # Sample 100% of available clients for training
    fraction_evaluate=0.5,  # Sample 50% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=10,  # Wait until all 10 clients are available
)

# Specify client resources if you need GPU (defaults to 1 CPU and 0 GPU)
client_resources = None
if DEVICE.type == "cuda":
    client_resources = {"num_gpus": 1}

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-04-16 00:37:36,328 | app.py:145 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-04-16 00:37:41,687	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# INFO flwr 2023-04-16 00:37:43,391 | app.py:179 | Flower VCE: Ray initialized with resources: {'CPU': 16.0, 'node:127.0.0.1': 1.0, 'memory': 5762303181.0, 'object_store_memory': 2147483648.0}
# INFO flwr 2023-04-16 00:37:43,392 | server.py:86 | Initializing global parameters
# INFO flwr 2023-04-16 00:37:43,393 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2023-04-16 00:37:46,941 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2023-04-16 00:37:46,942 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-04-16 00:37:46,942 | server.py:101 | FL starting
# DEBUG flwr 2023-04-16 00:37:46,943 | server.py:215 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-04-16 00:38:04,234 | server.py:229 | fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-04-16 00:38:04,258 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-04-16 00:38:04,260 | server.py:165 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:38:12,734 | server.py:179 | evaluate_round 1 received 5 results and 0 failures
# WARNING flwr 2023-04-16 00:38:12,735 | fedavg.py:273 | No evaluate_metrics_aggregation_fn provided
# DEBUG flwr 2023-04-16 00:38:12,736 | server.py:215 | fit_round 2: strategy sampled 10 clients (out of 10)
# (raylet) Spilled 2499 MiB, 28 objects, write throughput 637 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# DEBUG flwr 2023-04-16 00:38:27,694 | server.py:229 | fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:38:27,722 | server.py:165 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:38:34,052 | server.py:179 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:38:34,053 | server.py:215 | fit_round 3: strategy sampled 10 clients (out of 10)
# (raylet) Spilled 4704 MiB, 51 objects, write throughput 568 MiB/s.
# DEBUG flwr 2023-04-16 00:38:48,119 | server.py:229 | fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:38:48,146 | server.py:165 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:38:53,765 | server.py:179 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:38:53,766 | server.py:215 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-04-16 00:39:08,802 | server.py:229 | fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:39:08,823 | server.py:165 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:39:15,481 | server.py:179 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:39:15,482 | server.py:215 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-04-16 00:39:29,090 | server.py:229 | fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:39:29,135 | server.py:165 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# (raylet) Spilled 8530 MiB, 108 objects, write throughput 616 MiB/s.
# DEBUG flwr 2023-04-16 00:39:34,857 | server.py:179 | evaluate_round 5 received 5 results and 0 failures
# INFO flwr 2023-04-16 00:39:34,858 | server.py:144 | FL finished in 107.91728239899385
# INFO flwr 2023-04-16 00:39:34,860 | app.py:202 | app_fit: losses_distributed [(1, 0.062391321849823), (2, 0.054466436386108395), (3, 0.05174205174446106), (4, 0.04995295577049255), (5, 0.04815834560394287)]
# INFO flwr 2023-04-16 00:39:34,861 | app.py:203 | app_fit: metrics_distributed {}
# INFO flwr 2023-04-16 00:39:34,862 | app.py:204 | app_fit: losses_centralized []
# INFO flwr 2023-04-16 00:39:34,863 | app.py:205 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.062391321849823
# 	round 2: 0.054466436386108395
# 	round 3: 0.05174205174446106
# 	round 4: 0.04995295577049255
# 	round 5: 0.04815834560394287

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %%
# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=10,
    min_evaluate_clients=5,
    min_available_clients=10,
    evaluate_metrics_aggregation_fn=weighted_average,  # <-- pass the metric aggregation function
)

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-04-16 00:39:41,885 | app.py:145 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-04-16 00:39:47,664	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# INFO flwr 2023-04-16 00:39:49,390 | app.py:179 | Flower VCE: Ray initialized with resources: {'object_store_memory': 2147483648.0, 'node:127.0.0.1': 1.0, 'memory': 8211901236.0, 'CPU': 16.0}
# INFO flwr 2023-04-16 00:39:49,392 | server.py:86 | Initializing global parameters
# INFO flwr 2023-04-16 00:39:49,392 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2023-04-16 00:39:52,759 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2023-04-16 00:39:52,759 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-04-16 00:39:52,760 | server.py:101 | FL starting
# DEBUG flwr 2023-04-16 00:39:52,761 | server.py:215 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-04-16 00:40:07,357 | server.py:229 | fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-04-16 00:40:07,380 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-04-16 00:40:07,381 | server.py:165 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:40:12,907 | server.py:179 | evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:40:12,908 | server.py:215 | fit_round 2: strategy sampled 10 clients (out of 10)
# (raylet) Spilled 2499 MiB, 26 objects, write throughput 652 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# DEBUG flwr 2023-04-16 00:40:28,790 | server.py:229 | fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:40:28,817 | server.py:165 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:40:35,111 | server.py:179 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:40:35,112 | server.py:215 | fit_round 3: strategy sampled 10 clients (out of 10)
# (raylet) Spilled 5293 MiB, 62 objects, write throughput 767 MiB/s.
# DEBUG flwr 2023-04-16 00:40:48,084 | server.py:229 | fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:40:48,107 | server.py:165 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:40:53,643 | server.py:179 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:40:53,644 | server.py:215 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-04-16 00:41:07,890 | server.py:229 | fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:41:07,914 | server.py:165 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:41:13,529 | server.py:179 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-04-16 00:41:13,530 | server.py:215 | fit_round 5: strategy sampled 10 clients (out of 10)
# (raylet) Spilled 8675 MiB, 100 objects, write throughput 782 MiB/s.
# DEBUG flwr 2023-04-16 00:41:26,330 | server.py:229 | fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-04-16 00:41:26,354 | server.py:165 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-04-16 00:41:33,165 | server.py:179 | evaluate_round 5 received 5 results and 0 failures
# INFO flwr 2023-04-16 00:41:33,166 | server.py:144 | FL finished in 100.40765506401658
# INFO flwr 2023-04-16 00:41:33,167 | app.py:202 | app_fit: losses_distributed [(1, 0.06279158549308776), (2, 0.05475127019882202), (3, 0.05271560854911804), (4, 0.050009317064285276), (5, 0.04849180064201355)]
# INFO flwr 2023-04-16 00:41:33,168 | app.py:203 | app_fit: metrics_distributed {'accuracy': [(1, 0.2832), (2, 0.3644), (3, 0.396), (4, 0.4136), (5, 0.43079999999999996)]}
# INFO flwr 2023-04-16 00:41:33,168 | app.py:204 | app_fit: losses_centralized []
# INFO flwr 2023-04-16 00:41:33,168 | app.py:205 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.06279158549308776
# 	round 2: 0.05475127019882202
# 	round 3: 0.05271560854911804
# 	round 4: 0.050009317064285276
# 	round 5: 0.04849180064201355
# History (metrics, distributed):
# {'accuracy': [(1, 0.2832), (2, 0.3644), (3, 0.396), (4, 0.4136), (5, 0.43079999999999996)]}
